# %% [markdown]
# # TP01 \- Deepnote Soria Demian

# %% [markdown]
# Soy Soria Demian profesor de fisica y estudiante de la tecnicatura de ciencia de datos e ia\.
# Mis espectativas para la materia son ampliar mis conocimientos en codigo, ia y desarrollo; tambien trabajar en equipo para conocer las diferentes perspectivas a la hora de encarar el desarrollo de trabajos,ideas,codigo,etc\.

# %%
print ("hace un tiempo no coodeo con phyton,el resumen de la clase fue muy bueno para refrescar la memoria y volver a empezar")
# Out:
# hace un tiempo no coodeo con phyton,el resumen de la clase fue muy bueno para refrescar la memoria y volver a empezar

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=278f5484-02d4-449d-99ec-d114e2c44191' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
